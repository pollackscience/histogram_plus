# %%
import numpy as np
import matplotlib.pyplot as plt
from histogram_plus import hist

# %matplotlib inline
plt.rcParams['figure.figsize'] = (12,8)

# %%
np.random.seed(8008)
data = np.random.normal(0, 1, size=1000)
weights = np.random.uniform(1,2, size=1000)
weights2 = np.random.uniform(0.1,200, size=1000)
weights3 = np.random.uniform(0.1,0.3, size=1000)
data2 = np.random.normal(3, 1, size=1000)
data3 = np.random.normal(6, 1, size=1000)
data4 = np.random.normal(6, 1, size=100)
weights4 = np.random.uniform(1,2, size=100)
data_uni = np.random.uniform(1,10, size=1000)

data_mixed_uni = np.concatenate([np.random.uniform(1,10, size=5000), np.random.uniform(2,5, size=600),
                                 np.random.uniform(6,7, size=300)])

# %%
bc, be, _ = hist(data, weightsnormed=True)
# Out:
# 1.0

# %%
types = ['bar', 'stepfilled', 'step', 'marker']
#types=['marker']
norms = [False, True]
#norms = [False]
scale = [None, 0.5, 2, 'binwidth']
#scale = [None, 2, 'binwidth']
#scale = [None, 'binwidth']
#bins = [30, 'auto', 100]
bins = [30, 'blocks']
ws = [None, weights]
#bins=['blocks']
#ws = [weights]
for t in types:
    for n in norms:
        for s in scale:
            for b in bins:
                for iw, w in enumerate(ws):
                    plt.figure()
                    plt.title('type: {0}, norm: {1}, scale: {2}, binning: {3}, weights: {4}'.format(t, n, s, b, iw))
                    hist(data, bins=b, histtype=t, normed=n, scale=s, errorbars=True, weights=w, alpha=0.5, label='d1')                 
                    plt.legend()

# %%
stack_d_test = [sorted(data)[20:-20]]*2
#oh = hist([data,data2], bins=20, weights=[weights,weights3], errorbars=True, histtype='stepfilled',
#          stacked=True, err_style='band', normed=False, err_type='sumW2')
plt.figure()
oh = hist([data,data2], bins=20, errorbars=True, histtype='stepfilled',
          stacked=True, err_style='line', normed=True, scale=2, err_color='grey')
#o = hist(stack_d_test, bins=30, errorbars=False, histtype='step', stacked=True, err_style='line', normed=True, range=(-1,1), scale=2)
#plt.figure()
#op = plt.hist(stack_d_test, bins=30, alpha=0.5, histtype='stepfilled',stacked=True, normed=True, range=(-1,1))

#plt.title('type: {0}, norm: {1}, scale: {2}, binning: {3}'.format(t, n, s, b))
#hist(data, bins=20, histtype='stepfilled', normed=True, scale='binwidth', errorbars=True, color='C6')
#print o
#print op
#np.sum(o[0][1])*(o[1][1]-o[1][0])

# %%
_ = hist(data2, bins=30, weights=weights2, histtype='stepfilled', errorbars=True)
plt.figure()
_ = hist(data2, bins=30, weights=weights2, histtype='stepfilled', errorbars=True, err_type='gaussian')

# %%
_ = hist(data2, bins=30, histtype='marker', errorbars=True, scale='binwidth',)
_ = hist(data2, bins='blocks', histtype='stepfilled', errorbars=True, scale='binwidth', p0=0.01)
plt.title('Unweighted dist.')
plt.figure()
_ = hist(data2, weights=weights, bins=30, histtype='marker', errorbars=True, scale='binwidth')
_ = hist(data2, weights=weights, bins='blocks', histtype='stepfilled', errorbars=True, scale='binwidth', p0=0.01)
plt.title('Weighted dist.')

# %%
data_uni = range(0,100)
weights_spec = ([1]*4+[10]+[1]*5)*10
_ = hist(data_uni, weights=weights_spec, bins='block', histtype='stepfilled', errorbars=True, err_style='band', scale='binwidth', p0=0.1)

# %%
oh = hist(data, bins='blocks', weights=weights, errorbars=True, histtype='stepfilled')

# %%
oh = hist(data_3_uni, bins=500, histtype='stepfilled', scale='binwidth', alpha=0.2)
oh = hist(data_3_uni, bins=4, histtype='step', scale='binwidth', alpha=0.8)
oh = hist(data_3_uni, bins='blocks', histtype='step', scale='binwidth', p0=0.01, alpha=0.8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-d7a7dbfef0ef> in <module>()
# ----> 1 oh = hist(data_3_uni, bins=500, histtype='stepfilled', scale='binwidth', alpha=0.2)
#       2 oh = hist(data_3_uni, bins=4, histtype='step', scale='binwidth', alpha=0.8)
#       3 oh = hist(data_3_uni, bins='blocks', histtype='step', scale='binwidth', p0=0.01, alpha=0.8)
#
# NameError: name 'data_3_uni' is not defined

# %%
#oh = hist(data_dbl, bins='blocks', histtype='stepfilled', scale='binwidth', p0=0.2)
oh = hist(data_mixed_uni, bins=100, histtype='stepfilled', scale='binwidth')
plt.title('Uniform Binning', fontsize=30)
plt.ylabel(r'$\frac{N}{\Delta X}$', fontsize=30)
plt.figure()
oh = hist(data_mixed_uni, bins=25, histtype='stepfilled', scale='binwidth')
plt.title('Uniform Binning', fontsize=30)
plt.ylabel(r'$\frac{N}{\Delta X}$', fontsize=30)
plt.figure()
oh = hist(data_mixed_uni, bins='blocks', histtype='stepfilled', scale='binwidth', color='C2', p0=0.02)
plt.title('Bayesian Blocks', fontsize=30)
plt.ylabel(r'$\frac{N}{\Delta X}$', fontsize=30)

# %%
data_dbl = np.concatenate([np.random.laplace(6,2, size=5000), np.random.uniform(1,0.15, size=100)])

# %%
#oh = hist(data_dbl, bins='blocks', histtype='stepfilled', scale='binwidth', p0=0.2)
oh = hist(data_dbl, bins=200, histtype='stepfilled', scale='binwidth')
plt.title('Too Many Bins?', fontsize=30)
plt.ylabel(r'$\frac{N}{\Delta X}$', fontsize=30)
plt.figure()
oh = hist(data_dbl, bins=20, histtype='stepfilled', scale='binwidth', color='C1')
plt.title('Too Few Bins?', fontsize=30)
plt.ylabel(r'$\frac{N}{\Delta X}$', fontsize=30)
plt.figure()
oh = hist(data_dbl, bins='blocks', histtype='stepfilled', scale='binwidth', color='C2', p0=0.05)
plt.title('Just Right?', fontsize=30)
plt.ylabel(r'$\frac{N}{\Delta X}$', fontsize=30)

# %%
oh = hist(data_mixed_uni, bins=35, histtype='marker', errorbars=True, scale='binwidth', alpha=0.7)
oh = hist(data_mixed_uni, bins='blocks', histtype='bar', scale='binwidth', p0=0.01, alpha=0.5)
#plt.title('Toy Data', fontsize=30)
plt.ylabel(r'$\frac{N}{\Delta X}$', fontsize=30)

# %%
np.concatenate([1,4,5,6])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-647ada4f8e51> in <module>()
# ----> 1 np.concatenate([1,4,5,6])
#
# ValueError: zero-dimensional arrays cannot be concatenated
