# %%
import numpy as np
import matplotlib.pyplot as plt
from histogram_plus.hist_funcs import hist

# %matplotlib inline
plt.rcParams['figure.figsize'] = (12,8)

# %%
data = np.random.normal(0, 1, size=1000)

# %%
hist(data, bins=30, histtype='marker', alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-21-0ae4bdd1a676> in <module>()
# ----> 1 hist(data, bins=30, histtype='marker', alpha=0.5)
#
# /Users/brianpollack/Coding/histogram_plus/histogram_plus/hist_funcs.py in hist(***failed resolving arguments***)
#     293         bc = bin_content_scaled
#     294     except:
# --> 295         bc = bin_content
#     296     return bc, bins, vis_objects
#     297
#
# UnboundLocalError: local variable 'bin_content' referenced before assignment

# %%
bc, be, patch = plt.hist(data, bins=20, alpha=0.5, histtype='bar')
#plt.hist(data, bins=30, weights=[2]*len(data), alpha=0.5)

# %%
patch[0]

# %%
bc
# Out:
# array([   1.,    2.,    7.,   17.,   32.,   59.,  100.,  112.,  120.,
#         128.,  123.,  110.,   81.,   52.,   27.,   12.,   11.,    4.,
#           1.,    1.])
