# %%
import numpy as np
import matplotlib.pyplot as plt
from histogram_plus.hist_funcs import hist

# %matplotlib inline
plt.rcParams['figure.figsize'] = (12,8)

# %%
data = np.random.normal(0, 1, size=1000)

# %%
types = ['bar', 'stepfilled', 'step', 'marker']
norms = [True, False]
scale = [0.5, 2, 'binwidth']
for t in types:
    for n in norms:
        for s in scale:
            plt.figure()
            hist(data, bins=30, histtype=t, normed=n, scale=s, alpha=0.5)
            plt.title(' '.join([t,str(n),str(s)]))
# Out:
# doing std hist!
# 5
# doing std hist!
# 5
# doing std hist!
# 6
# doing std hist!
# 3
# doing std hist!
# 3
# doing std hist!
# 4
# doing std hist!
# 5
# doing std hist!
# 5
# doing std hist!
# 6
# doing std hist!
# 3
# doing std hist!
# 3
# doing std hist!
# 4
# doing std hist!
# 5
# doing std hist!
# 5
# doing std hist!
# 6
# doing std hist!
# 3
# doing std hist!
# /Users/brianpollack/Coding/histogram_plus/histogram_plus/hist_funcs.py:391: RuntimeWarning: invalid value encountered in true_divide
#   err_scale = (bin_content_norm/bin_content_no_norm)*scale
# /Users/brianpollack/Coding/histogram_plus/histogram_plus/hist_funcs.py:295: RuntimeWarning: invalid value encountered in true_divide
#   err_scale = (bin_content_norm/bin_content_no_norm)*scale
# 3
# doing std hist!
# 4

# %%
bc, be, patch = plt.hist(data, bins=20, alpha=0.5, histtype='stepfilled')
#plt.hist(data, bins=30, weights=[2]*len(data), alpha=0.5)

# %%
patch[0]

# %%
bc
# Out:
# array([   1.,    2.,    7.,   17.,   32.,   59.,  100.,  112.,  120.,
#         128.,  123.,  110.,   81.,   52.,   27.,   12.,   11.,    4.,
#           1.,    1.])

# %%
plt.setp?
